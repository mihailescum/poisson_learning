# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import cdist

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("paper", font_scale=1.2)

cm = 1/2.54  # centimeters in inches
scaling = 1
plt.rc("figure", figsize=(16*scaling*cm,7*scaling))

import poissonlearning as pl

import storage
import plotting

plotting.setup(latex=True)

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
SAVE_PLOTS = True
NUM_PLOTTING_POINTS = 5000

# %% [markdown]
# ### Convenience functions

# %%
def compute_analytic_solution(xy, z1, z2):
    # Compute the analytic continuum limit
    green_first_label = pl.datasets.one_circle.greens_function(x=xy, z=z1)
    green_second_label = pl.datasets.one_circle.greens_function(x=xy, z=z2)
    solution_analytic = -0.5 * green_first_label + 0.5 * green_second_label
    return 2 * solution_analytic


def compute_errors(experiments):
    for experiment in experiments:
        solution = experiment["solution"]
        xy = solution[["x", "y"]].to_numpy()
        z = solution["z"].to_numpy()

        z1 = experiment["label_locations"][0]
        z2 = experiment["label_locations"][1]
        analytic = compute_analytic_solution(xy, z1, z2)

        mask_infty = np.isfinite(analytic)

        # For knn graphs compute the scale
        if "n_neighbors" in experiment:
            knn_scale = np.median((analytic[mask_infty] / z[mask_infty]))
            z *= knn_scale
            experiment["knn_scale"] = knn_scale
            print(f"n={experiment['n']}; n_neighbors={experiment['n_neighbors']} scale={knn_scale}")

        error_L1 = np.abs(z[mask_infty] - analytic[mask_infty]).mean()
        experiment["error_L1"] = error_L1

        # Compute error to dirac experiment, if exists
        e_dirac = list(
            filter(
                lambda x: x["seed"] == experiment["seed"]
                and x["n"] == experiment["n"]
                and ((
                        "eps" in experiment
                        and "eps" in x
                        and np.isclose(x["eps"], experiment["eps"])
                    ) 
                    or (
                        "n_neighbors" in experiment
                        and "n_neighbors" in x
                        and x["n_neighbors"] == experiment["n_neighbors"]
                    )
                )
                and np.allclose(x["label_locations"], experiment["label_locations"])
                and x["kernel"] == experiment["kernel"]
                and x["bump"] == "dirac",
                experiments,
            )
        )
        if e_dirac:
            error_L1_dirac = np.abs(solution["z"] - e_dirac[0]["solution"]["z"]).mean()
            experiment["error_L1_dirac"] = error_L1_dirac

# %% [markdown]
# ### Load experiments and compute errors

# %%
experiments = storage.load_results(name="one_circle", folder="../results")
compute_errors(experiments)
# Out:
# n=10000; n_neighbors=5 scale=0.035313685702513475
# n=10000; n_neighbors=5 scale=0.035313685702513475
# n=10000; n_neighbors=5 scale=0.035313685702513475
# n=10000; n_neighbors=5 scale=0.03524035151751619
# n=10000; n_neighbors=10 scale=0.42570166328014164
# n=10000; n_neighbors=10 scale=0.42570166328014164
# n=10000; n_neighbors=10 scale=0.42570166328014164
# n=10000; n_neighbors=10 scale=0.42593609023809675
# n=10000; n_neighbors=15 scale=1.2650102494404698
# n=10000; n_neighbors=15 scale=1.2650102494404698
# n=10000; n_neighbors=15 scale=1.2650102494404698
# n=10000; n_neighbors=15 scale=1.2686364753520176
# n=30000; n_neighbors=5 scale=0.032524653625621305
# n=30000; n_neighbors=5 scale=0.032524653625621305
# n=30000; n_neighbors=5 scale=0.032521522117611834
# n=30000; n_neighbors=5 scale=0.03287906623280147
# n=30000; n_neighbors=10 scale=0.4180753786504111
# n=30000; n_neighbors=10 scale=0.4180753786504111
# n=30000; n_neighbors=10 scale=0.4178713879751149
# n=30000; n_neighbors=10 scale=0.4217401886931724
# n=30000; n_neighbors=15 scale=1.2671970486576156
# n=30000; n_neighbors=15 scale=1.2671970486576156
# n=30000; n_neighbors=15 scale=1.266383617851567
# n=30000; n_neighbors=15 scale=1.2765329286623022
# n=50000; n_neighbors=5 scale=0.03172208086332564
# n=50000; n_neighbors=5 scale=0.03172208086332564
# n=50000; n_neighbors=5 scale=0.031713801262639174
# n=50000; n_neighbors=5 scale=0.032109018664537685
# n=50000; n_neighbors=10 scale=0.4161213187926508
# n=50000; n_neighbors=10 scale=0.4161213187926508
# n=50000; n_neighbors=10 scale=0.4160867694144524
# n=50000; n_neighbors=10 scale=0.41779501754403475
# n=100000; n_neighbors=5 scale=0.03363445243842499
# n=100000; n_neighbors=5 scale=0.03363445243842499
# n=100000; n_neighbors=5 scale=0.033658291729067404
# n=100000; n_neighbors=5 scale=0.03355245888084282
# n=300000; n_neighbors=5 scale=0.03342471269708982
# n=300000; n_neighbors=5 scale=0.03342471269708982
# n=300000; n_neighbors=5 scale=0.03342886286915153
# n=300000; n_neighbors=5 scale=0.03365321309479828
# n=700000; n_neighbors=5 scale=0.03314578362687651
# n=700000; n_neighbors=5 scale=0.03314578362306246
# n=700000; n_neighbors=5 scale=0.03324371113825467
# n=700000; n_neighbors=5 scale=0.033337649586338024
# n=10000; n_neighbors=5 scale=0.03230203173607754
# n=10000; n_neighbors=5 scale=0.03230203173607754
# n=10000; n_neighbors=5 scale=0.032304805378200636
# n=10000; n_neighbors=5 scale=0.03252851822908823
# n=10000; n_neighbors=10 scale=0.42105127277276544
# n=10000; n_neighbors=10 scale=0.42105127277276544
# n=10000; n_neighbors=10 scale=0.421128258011612
# n=10000; n_neighbors=10 scale=0.42008811313271377
# n=10000; n_neighbors=15 scale=1.2916902110681827
# n=10000; n_neighbors=15 scale=1.2916902110681827
# n=10000; n_neighbors=15 scale=1.2916259617472816
# n=10000; n_neighbors=15 scale=1.2842946847576966
# n=30000; n_neighbors=5 scale=0.03356011131978798
# n=30000; n_neighbors=5 scale=0.03356011131978798
# n=30000; n_neighbors=5 scale=0.03356077404178433
# n=30000; n_neighbors=5 scale=0.03362443002552823
# n=30000; n_neighbors=10 scale=0.4281278317068722
# n=30000; n_neighbors=10 scale=0.4281278317068722
# n=30000; n_neighbors=10 scale=0.42811598471039614
# n=30000; n_neighbors=10 scale=0.42794818596699863
# n=30000; n_neighbors=15 scale=1.2860120379198934
# n=30000; n_neighbors=15 scale=1.2860120379198934
# n=30000; n_neighbors=15 scale=1.285781899361162
# n=30000; n_neighbors=15 scale=1.2863808598507247
# n=50000; n_neighbors=5 scale=0.03281239681721457
# n=50000; n_neighbors=5 scale=0.03281239681721457
# n=50000; n_neighbors=5 scale=0.0328161968746076
# n=50000; n_neighbors=5 scale=0.032987012384594845
# n=50000; n_neighbors=10 scale=0.42644789146466056
# n=50000; n_neighbors=10 scale=0.42644789146466056
# n=50000; n_neighbors=10 scale=0.4264797309481141
# n=50000; n_neighbors=10 scale=0.42874072992149936
# n=100000; n_neighbors=5 scale=0.03284728829992421
# n=100000; n_neighbors=5 scale=0.03284728829992421
# n=100000; n_neighbors=5 scale=0.03296169859998577
# n=100000; n_neighbors=5 scale=0.03312241435107469
# n=300000; n_neighbors=5 scale=0.03346796741126629
# n=300000; n_neighbors=5 scale=0.03346796741126629
# n=300000; n_neighbors=5 scale=0.03352313594123969
# n=300000; n_neighbors=5 scale=0.033562728511765574
# n=700000; n_neighbors=5 scale=0.033603847899090045
# n=700000; n_neighbors=5 scale=0.03360411846673088
# n=700000; n_neighbors=5 scale=0.033586195317260994
# n=700000; n_neighbors=5 scale=0.0336080291704962
# n=10000; n_neighbors=5 scale=0.032440613876302496
# n=10000; n_neighbors=5 scale=0.032440613876302496
# n=10000; n_neighbors=5 scale=0.03243469691674405
# n=10000; n_neighbors=5 scale=0.031759305868054435
# n=10000; n_neighbors=10 scale=0.43224665320945244
# n=10000; n_neighbors=10 scale=0.43224665320945244
# n=10000; n_neighbors=10 scale=0.43237519057575624
# n=10000; n_neighbors=10 scale=0.4294489433810628
# n=10000; n_neighbors=15 scale=1.289170538245225
# n=10000; n_neighbors=15 scale=1.289170538245225
# n=10000; n_neighbors=15 scale=1.2895975146194938
# n=10000; n_neighbors=15 scale=1.2892743983537924
# n=30000; n_neighbors=5 scale=0.03418588059115252
# n=30000; n_neighbors=5 scale=0.03418591275352508
# n=30000; n_neighbors=5 scale=0.03418465750988458
# n=30000; n_neighbors=5 scale=0.034310585034704126
# n=30000; n_neighbors=10 scale=0.4262686155199986
# n=30000; n_neighbors=10 scale=0.42628220264377586
# n=30000; n_neighbors=10 scale=0.42622554163786236
# n=30000; n_neighbors=10 scale=0.42433939875111726
# n=30000; n_neighbors=15 scale=1.2782428046842162
# n=30000; n_neighbors=15 scale=1.278274317706891
# n=30000; n_neighbors=15 scale=1.2781864565327528
# n=30000; n_neighbors=15 scale=1.2739089930969973
# n=50000; n_neighbors=5 scale=0.034937810661856014
# n=50000; n_neighbors=5 scale=0.034937806841523714
# n=50000; n_neighbors=5 scale=0.03493583927049931
# n=50000; n_neighbors=5 scale=0.03508354965698856
# n=50000; n_neighbors=10 scale=0.4338271077166526
# n=50000; n_neighbors=10 scale=0.43382739667042336
# n=50000; n_neighbors=10 scale=0.4338084587653503
# n=50000; n_neighbors=10 scale=0.4328784249096286
# n=100000; n_neighbors=5 scale=0.03298480699295955
# n=100000; n_neighbors=5 scale=0.03298465289735226
# n=100000; n_neighbors=5 scale=0.032981610604775474
# n=100000; n_neighbors=5 scale=0.03297500967280559
# n=300000; n_neighbors=5 scale=0.03390888391312451
# n=300000; n_neighbors=5 scale=0.03390865212663882
# n=300000; n_neighbors=5 scale=0.03398591348525201
# n=300000; n_neighbors=5 scale=0.033891530980323895
# n=700000; n_neighbors=5 scale=0.03377814471286753
# n=700000; n_neighbors=5 scale=0.03377820076218919
# n=700000; n_neighbors=5 scale=0.033765375744907164
# n=700000; n_neighbors=5 scale=0.033692404477505544
# n=10000; n_neighbors=5 scale=0.0345025724702069
# n=10000; n_neighbors=5 scale=0.0345025724702069
# n=10000; n_neighbors=5 scale=0.0345012574254169
# n=10000; n_neighbors=5 scale=0.03370184406097383
# n=10000; n_neighbors=10 scale=0.43603463576079143
# n=10000; n_neighbors=10 scale=0.43603463576079143
# n=10000; n_neighbors=10 scale=0.43606983406621735
# n=10000; n_neighbors=10 scale=0.43202980829069104
# n=10000; n_neighbors=15 scale=1.2947430533287032
# n=10000; n_neighbors=15 scale=1.2947430533287032
# n=10000; n_neighbors=15 scale=1.295048212488928
# n=10000; n_neighbors=15 scale=1.2893559613294427
# n=30000; n_neighbors=5 scale=0.034377206691365826
# n=30000; n_neighbors=5 scale=0.034377206691365826
# n=30000; n_neighbors=5 scale=0.03437566796073104
# n=30000; n_neighbors=5 scale=0.034242217016473446
# n=30000; n_neighbors=10 scale=0.4320654435262178
# n=30000; n_neighbors=10 scale=0.4320654435262178
# n=30000; n_neighbors=10 scale=0.43212304344758945
# n=30000; n_neighbors=10 scale=0.431808737925621
# n=30000; n_neighbors=15 scale=1.2917903222292382
# n=30000; n_neighbors=15 scale=1.2917903222292382
# n=30000; n_neighbors=15 scale=1.2919101103874226
# n=30000; n_neighbors=15 scale=1.2937654923165125
# n=50000; n_neighbors=5 scale=0.03420841591693899
# n=50000; n_neighbors=5 scale=0.034207935749339724
# n=50000; n_neighbors=5 scale=0.034221175045254806
# n=50000; n_neighbors=5 scale=0.03419558219121342
# n=50000; n_neighbors=10 scale=0.43066152553619025
# n=50000; n_neighbors=10 scale=0.4306342162835187
# n=50000; n_neighbors=10 scale=0.43088150265656777
# n=50000; n_neighbors=10 scale=0.4323904735019798
# n=100000; n_neighbors=5 scale=0.03366509705201728
# n=100000; n_neighbors=5 scale=0.03366504156200265
# n=100000; n_neighbors=5 scale=0.03366565323894503
# n=100000; n_neighbors=5 scale=0.03370107020351666
# n=300000; n_neighbors=5 scale=0.03358515274915089
# n=300000; n_neighbors=5 scale=0.03358508130510819
# n=300000; n_neighbors=5 scale=0.03359359204975828
# n=300000; n_neighbors=5 scale=0.033514914228544995
# n=700000; n_neighbors=5 scale=0.03340622103726575
# n=700000; n_neighbors=5 scale=0.03340652570003453
# n=700000; n_neighbors=5 scale=0.033425099413261626
# n=700000; n_neighbors=5 scale=0.03346795006437733

# %% [markdown]
# ## Plotting

# %%
colors = plotting.get_plot_colors(n=5)

# %% [markdown]
# ### solution vs analytic

# %%
bump_width = "dirac"
n = 100000
ex_plot = list(
    filter(lambda x: 
        x["n"] == n 
        and x["bump"] == bump_width
        and "eps" in x,
        experiments,
    )
)[0]

solution_plot = ex_plot["solution"]
sample = solution_plot.sample(NUM_PLOTTING_POINTS, random_state=1)

xy = sample[["x", "y"]].to_numpy()
dist = cdist(xy, xy, metric="euclidean")

# %%
fig = plt.figure(figsize=(10, 4))
ax_solution = fig.add_subplot(1, 2, 1, projection="3d")
plotting.plot_graph_function_scatter(
    ax_solution, xy, sample["z"].to_numpy(), dist=dist, max_dist=0.1,
)

z1 = ex_plot["label_locations"][0]
z2 = ex_plot["label_locations"][1]
analytic = compute_analytic_solution(xy, z1, z2)
ax_analytic = fig.add_subplot(1, 2, 2, projection="3d")
plotting.plot_graph_function_with_triangulation(
    ax_analytic, xy, analytic, dist=dist, max_dist=0.1,
)
# fig_results.suptitle(f"Discrete solution [n={n}] vs analytic solution")
fig.tight_layout()

if SAVE_PLOTS:
    fig.savefig(f"../plots/one_circle_demo.png", bbox_inches="tight")

# %% [markdown]
# ### Error for Dirac RHS

# %%
selected_experiments = {
    kernel: list(
        filter(
            lambda x: x["kernel"] == kernel
            and x["bump"] == "dirac"
            and "eps" in x
            and (
                x["n"] != 100000 or np.isclose(x["eps"], 0.00930454)
            ),  # Keep only eps = np.log(n) ** (1 / 15) * conn_radius
            experiments,
        )
    )
    for kernel in ["gaussian"]
}

n_error = sorted(list(set([e["n"] for e in list(selected_experiments.values())[0]])))
error = {kernel: {} for kernel in selected_experiments.keys()}
for kernel, experiments_with_kernel in selected_experiments.items():
    for n in n_error:
        ex = list(filter(lambda x: x["n"] == n, experiments_with_kernel))
        error[kernel][n] = {}
        error[kernel][n]["mean"] = np.mean([e["error_L1"] for e in ex])
        error[kernel][n]["max"] = np.max([e["error_L1"] for e in ex])
        error[kernel][n]["min"] = np.min([e["error_L1"] for e in ex])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
plotting.error_plot(error, ax, fit="polynomial")
# ax_error.set_title(f"L1 Error compared with RHS {bump_width} to analytic solution")
ax.legend()
ax.set_xlabel(r"$n$")
ax.set_ylabel(r"$\lVert u_n - u \rVert_{L^1 \left(B_1 \right)}$")
fig.tight_layout()

if SAVE_PLOTS:
    fig.savefig(f"../plots/one_circle_dirac_n.pdf", bbox_inches="tight")
# Out:
# /home/max/Dokumente/Studium/Masterarbeit/code/poisson_learning/examples/plotting.py:119: RuntimeWarning: overflow encountered in power
#   return a * (X ** (-n))
# INFO:plotting:Fitted parameters: [4.14933985e+03 9.69459093e-01]

# %% [markdown]
# ### Error for Dirac RHS with KNN graph

# %%
selected_experiments = {
    kernel: list(
        filter(
            lambda x: x["kernel"] == kernel
            and x["bump"] == "dirac"
            and "n_neighbors" in x,
            experiments,
        )
    )
    for kernel in ["gaussian"]
}

n_error = sorted(list(set([e["n"] for e in list(selected_experiments.values())[0]])))
error = {kernel: {} for kernel in selected_experiments.keys()}
for kernel, experiments_with_kernel in selected_experiments.items():
    for n in n_error:
        ex = list(filter(lambda x: x["n"] == n, experiments_with_kernel))
        if n == 100000:
            v = ex
        error[kernel][n] = {}
        error[kernel][n]["mean"] = np.mean([e["error_L1"] for e in ex])
        error[kernel][n]["max"] = np.max([e["error_L1"] for e in ex])
        error[kernel][n]["min"] = np.min([e["error_L1"] for e in ex])

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
plotting.error_plot(error, ax, fit="polynomial")
# ax_error.set_title(f"L1 Error compared with RHS {bump_width} to analytic solution")
ax.legend()
ax.set_xlabel(r"$n$")
ax.set_ylabel(r"$\lVert u_n - u \rVert_{L^1 \left(B_1 \right)}$")
fig.tight_layout()

if SAVE_PLOTS:
    fig.savefig(f"../plots/one_circle_dirac_n_knn.pdf", bbox_inches="tight")
# Out:
# /home/max/Dokumente/Studium/Masterarbeit/code/poisson_learning/examples/plotting.py:119: RuntimeWarning: overflow encountered in power
#   return a * (X ** (-n))
# INFO:plotting:Fitted parameters: [0.17199179 0.27063953]

# %% [markdown]
# ### Convergence of bump RHS

# %%
selected_experiments = {
    f"bump={bump}": list(
        filter(lambda x:
            x["bump"] == bump
            and x["kernel"] == "gaussian"
            and "eps" in x,
            experiments,
        )
    )
    for bump in [0.001, 0.01, 0.1]
}

n_error = sorted(list(set([e["n"] for e in list(selected_experiments.values())[0]])))
error = {bump: {} for bump in selected_experiments.keys()}
for bump, experiments_with_bump in selected_experiments.items():
    for n in n_error:
        ex = list(filter(lambda x: x["n"] == n, experiments_with_bump))
        if ex:
            error[bump][n] = {}
            error_list = [e["error_L1_dirac"] for e in ex if e["error_L1_dirac"] > 0]
            error[bump][n]["mean"] = np.mean(error_list) if error_list else np.nan
            error[bump][n]["max"] = np.max(error_list) if error_list else np.nan
            error[bump][n]["min"] = np.min(error_list) if error_list else np.nan

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
for i, (bump, e) in enumerate(error.items()):
    plotting.error_plot({bump: e}, ax, fit=None, label=bump, c=colors[i])

    # ax.set_xscale("log")
    # ax.set_title("L1 error of solution with dirac RHS")
ax.legend()
ax.set_yscale("log")
ax.set_xlabel(r"$n$")
ax.set_ylabel(r"$\lVert u_n - u \rVert_{L^1 \left((0, 1) \right)}$")

#ax.set_ylim(0, 2.5e-3)
fig.tight_layout()
if SAVE_PLOTS:
    fig.savefig(f"../plots/line_dirac_n_{bump}.pdf", bbox_inches="tight")

# %% [markdown]
# ### Convergence for different choices of epsilon

# %%
n = 100000
selected_experiments = {
    kernel: list(
        filter(
            lambda x: x["kernel"] == kernel
            and x["n"] == n
            and x["bump"] == "dirac"
            and "eps" in x,
            experiments,
        )
    )
    for kernel in ["gaussian"]
}
eps_error = list(set([e["eps"] for e in list(selected_experiments.values())[0]]))
eps_error = sorted(eps_error)
error = {kernel: {} for kernel in selected_experiments.keys()}
n_connected_component = {kernel: {} for kernel in selected_experiments.keys()}
for kernel, experiments_with_kernel in selected_experiments.items():
    for eps in eps_error:
        ex = list(filter(lambda x: np.isclose(x["eps"], eps), experiments_with_kernel))
        error[kernel][eps] = {}
        error[kernel][eps]["mean"] = np.mean([e["error_L1"] for e in ex])
        error[kernel][eps]["max"] = np.max([e["error_L1"] for e in ex])
        error[kernel][eps]["min"] = np.min([e["error_L1"] for e in ex])

        n_connected_component[kernel][eps] = {}
        n_connected_component[kernel][eps]["mean"] = np.mean([e["solution"].shape[0] for e in ex])
        n_connected_component[kernel][eps]["max"] = np.max([e["solution"].shape[0] for e in ex])
        n_connected_component[kernel][eps]["min"] = np.min([e["solution"].shape[0] for e in ex])

# %%
for kernel, e in error.items():
    fig, ax = plt.subplots(1, 1, figsize=(10, 4))
    plotting.error_plot({kernel: e}, ax)#, fit="polynomial")

    ax.legend()
    ax.set_xlabel(fr"$h_{ {n} }$")
    ax.set_ylabel(fr"$\lVert u_{ {n} } - u \rVert_1$")
    #ax.set_xscale("log")

    ax_n = ax.twinx()
    plotting.error_plot({kernel: n_connected_component[kernel]}, ax_n, c="blue")#, fit="polynomial")
    ax_n.set_ylabel(r"\# nodes connected component")
    ax_n.grid(None)
    fig.tight_layout()
    if SAVE_PLOTS:
        fig.savefig(f"../plots/one_circle_convergence_eps.pdf", bbox_inches="tight")

# %%
ex = experiments[50]
u = ex["solution"]
ex
# Out:
# {'n': 100000,
#  'bump': 'dirac',
#  'kernel': 'gaussian',
#  'label_locations': array([[-0.66666666,  0.        ],
#         [ 0.66666666,  0.        ]]),
#  'seed': 0,
#  'eps': 0.010235,
#  'tol': 1e-08,
#  'max_iter': 200,
#  'hash': '26c165cb772a2042ce4ad71b5c73d0a4',
#  'solution':               x         y         z
#  0     -0.666667  0.000000  1.001500
#  1      0.666667  0.000000 -1.219855
#  2     -0.145183 -0.141051  0.096823
#  3     -0.081584  0.099357  0.065895
#  4     -0.359399  0.827105  0.131906
#  ...         ...       ...       ...
#  99989 -0.554993 -0.101013  0.482036
#  99990 -0.233489  0.020422  0.167658
#  99991  0.464222  0.749373 -0.180287
#  99992 -0.673808  0.353584  0.389588
#  99993  0.047987 -0.709901 -0.030943
#
#  [99994 rows x 3 columns],
#  'error_L1': 0.016153911207959747,
#  'error_L1_dirac': 0.0}

# %%
X = u[["x", "y"]].to_numpy()
X
dataset = pl.datasets.Dataset(X, np.zeros(X.shape[0]), "")

# %%
import utils
G, _ = utils.build_graph(dataset, ex, eps=ex["eps"])
# Out:
# INFO:utils:Creating weight matrix...

# %%
L = G.laplacian()

# %%
(L @ u["z"]) * 2 / utils.get_normalization_constant("gaussian", 2, [2]) * np.pi**2 / ex["n"] ** 2 / ex["eps"]**4
# Out:
# array([ 5.00000034e-01, -5.00000035e-01, -2.86225406e-12, ...,
#        -7.24499314e-10, -6.71772765e-16,  6.99763297e-18])
